# %%
# !git clone https://github.com/ultralytics/yolov5 # yolov5 코드 clone
# %cd yolov5
# !pip install -qr requirements.txt # 필수 라이브러리 설치
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12180, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 12180 (delta 1), reused 1 (delta 0), pack-reused 12173
# Receiving objects: 100% (12180/12180), 11.96 MiB | 25.74 MiB/s, done.
# Resolving deltas: 100% (8429/8429), done.
# /content/yolov5
#      |████████████████████████████████| 596 kB 9.7 MB/s

# %%
# %pwd
# Out:
# '/content/yolov5'

# %%
# !unzip ../runs.zip
# Out:
# Archive:  ../runs.zip
#    creating: runs/train/
#    creating: runs/train/exp/
#   inflating: runs/train/exp/confusion_matrix.png
#   inflating: runs/train/exp/events.out.tfevents.1651062462.846c43b8a9fc.192.0
#   inflating: runs/train/exp/F1_curve.png
#   inflating: runs/train/exp/hyp.yaml
#   inflating: runs/train/exp/labels.jpg
#   inflating: runs/train/exp/labels_correlogram.jpg
#   inflating: runs/train/exp/opt.yaml
#   inflating: runs/train/exp/P_curve.png
#   inflating: runs/train/exp/PR_curve.png
#   inflating: runs/train/exp/R_curve.png
#   inflating: runs/train/exp/results.csv
#   inflating: runs/train/exp/results.png
#   inflating: runs/train/exp/train_batch0.jpg
#   inflating: runs/train/exp/train_batch1.jpg
#   inflating: runs/train/exp/train_batch2.jpg
#   inflating: runs/train/exp/val_batch0_labels.jpg
#   inflating: runs/train/exp/val_batch0_pred.jpg
#   inflating: runs/train/exp/val_batch1_labels.jpg
#   inflating: runs/train/exp/val_batch1_pred.jpg
# ...

# %%
# !python detect.py --source "/content/test5.jpg" --save-txt --exist-ok --weights "/content/yolov5/runs/train/exp/weights/best.pt"
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/test5.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-163-gb53917d torch 1.11.0+cu113 CPU
#
# Fusing layers...
# Model summary: 213 layers, 7023610 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/test5.jpg: 640x640 1 Face, 2 Eyes, 1 Nose, 1 Mouth, 2 Ears, Done. (0.372s)
# Speed: 4.0ms pre-process, 372.1ms inference, 1.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp
# 4 labels saved to runs/detect/exp/labels

# %%
# !python detect.py --source "/content/test4.jpg" --exist-ok --nosave --weights "/content/yolov5/runs/train/exp/weights/best.pt"
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/test4.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=True, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-164-g177da7f torch 1.11.0+cu113 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7023610 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/test4.jpg: 352x640 1 Face, 2 Eyes, 3 Noses, 1 Mouth, 2 Ears, Done. (0.024s)
# Speed: 0.4ms pre-process, 24.5ms inference, 1.9ms NMS per image at shape (1, 3, 640, 640)

# %%
import os

os.system('python detect.py --source "/content/test4.jpg" --exist-ok --nosave --weights "/content/yolov5/runs/train/exp/weights/best.pt"')
# Out:
# 256
